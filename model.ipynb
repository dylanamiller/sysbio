# %%
include("InsRes.jl")
import .InsRes

# %%
InsRes.example()
# Out:
# Running AD Energy Metabolism Model...
#
# 1. Simulating healthy state...
# 2. Simulating insulin resistant state...
# 3. Creating plots...
# 4. Running sensitivity analysis for IDE level...
# Simulation complete!
